# %% [markdown]
# # Matlibs

# %% [markdown]
# string concatenation (aka how to put strings together)
# suppose we want to create a string that says "subscribe to ___"
# youtuber = "Dhruv Kirar" - some string varibale

# %% [markdown]
# We will use:
# print(f'subscribe to {youtuber}')

# %%
import random

# %%
def sample():
    adj = input('Adjective: ')
    
    verb1 = input('Verb 1:')
    verb2 = input('Verb 2:')
    
    famous_person= input('Famous Person: ')
    
    matlib = f"""Computer programming is {adj}! It makes me so excited all the time because
    I love to {verb1}.Stay hydrated and {verb2} like you are {famous_person}!"""
    
    return matlib

# %%
def A_Day_At_The_Zoo():
    adjective1 = input('Adjective 1: ')
    adjective2 = input('Adjective 2: ')
    adjective3 = input('Adjective 3: ')
    adjective4 = input('Adjective 4: ')
    
    verb1 = input('Verb 1(past tense): ')
    verb2 = input('Verb 2: ')
    verb3 = input('Verb 3(past tense): ')
    
    noun1 = input('Noun 1: ')
    noun2 = input('Noun 2: ')
    noun3 = input('Noun 3: ')
    
    adverb1 = input('Adverb 1: ')
    adverb2 = input('Adverb 2: ')
    adverb3 = input('Adverb 3: ')
    
    matlib = f"""Today I went to the zoo. I saw a(n) {adjective1}
    {noun1} jumping up and down in its tree.
    He {verb1} {adverb1} through the large tunnel
    that led to its {adjective2} {noun2}.
    I got some peanuts and passed\
    them through the cage to a gigantic gray {noun3}
    towering above my head. Feeding that animal made
    me hungry. I went to get a {adjective3} scoop
    of ice cream. It filled my stomach. Afterwards I had to
    {verb2} {adverb2} to catch our bus.
    When I got home I {verb3} my
    mom for a {adjective4} day at the zoo."""
    
    return matlib

# %%
def Make_Me_A_Video_Game():
    adjective1 = input('Adjective 1: ')
    adjective2 = input('Adjective 2: ')
    adjective3 = input('Adjective 3: ')
    adjective4 = input('Adjective 4: ')
    adjective5 = input('Adjective 5: ')
    adjective6 = input('Adjective 6: ')
    
    verb1 = input('Verb 1(past tense): ')
    
    noun1 = input('Noun 1(plural): ')
    noun2 = input('Noun 2(plural): ')
    noun3 = input('Noun 3(plural): ')
    noun4 = input('Noun 4(plural): ')
    noun5 = input('Noun 5(plural): ')
    
    number1 = input('Number(1-50): ')
    number2 = input('Number2: ')
    number3 = input('Number3: ')
    
    first_name = input('First Name: ')
    girl_name = input("Girl's Name: ")
    large_animal = input('Large Animal: ')
    small_animal = input('small Animal: ')
    
    matlib = f"""I, the {adjective1} and {adjective2}
    {first_name} has {verb1}
    {first_name}'s {adjective3}
    sister and plans to steal her {adjective4}
    {noun1}! What are a {large_animal} and backpacking {small_animal} to do?
    Before you can help {girl_name},
    you'll have to collect the {adjective5}
    {noun2} and {adjective6}
    {noun3} that open up the
    {number1} worlds connected to a
    {first_name} lair. There are
    {number2} {noun4} and
    {number3} {noun5} in the
    game, along with hundreds of other goodies for you to find."""
    
    return matlib

# %%
def In_The_Jungle():
    adjective1 = input('Adjective 1: ')
    adjective2 = input('Adjective 2: ')
    adjective3 = input('Adjective 3: ')
    adjective4 = input('Adjective 4: ')
    adjective5 = input('Adjective 5: ')
    adjective6 = input('Adjective 6: ')
    adjective7 = input('Adjective 7: ')
    
    verb1 = input('Verb 1: ')
    verb2 = input('Verb 2: ')
    verb3 = input('Verb 3: ')
    verb4 = input('Verb 4: ')
    
    noun1 = input('Noun 1: ')
    noun2 = input('Noun 2: ')
    noun3 = input('Noun 3: ')
    noun4 = input('Noun 4: ')
    
    matlib = f"""I walk through the color jungle. I take out my
    {adjective1} canteen. There's a
    {adjective2} parrot with a {adjective3}
    _______________({noun1}) in his mouth right there in front
    of me in the {adjective4} trees! I gaze at his
    {adjective5} {noun2}. A sudden
    sound awakes me from my daydream! A panther’s
    {verb1} in front of my head! I
    {verb2} his {adjective6}
    breath. I remember I have a packet of {noun3}
    that makes go into a deep slumber! I
    {verb3}it away from me in front of the
    {noun4}.Yes he's eating it! I
    {verb4} away through the
    {adjective7} jungle. I meet my parents at the
    tent. Phew! It’s been an exciting day in the jungle. """
    
    return matlib

# %%
def The_Fun_Park():
    adjective1 = input('Adjective 1: ')
    adjective2 = input('Adjective 2(-est): ')
    adjective3 = input('Adjective 3: ')

    
    verb1 = input('Verb 1(past tense): ')
    verb2 = input('Verb 2(past tense): ')
    
    noun1 = input('Noun 1(plural): ')
    noun2 = input('Noun 2: ')
    
    number1 = input('Number 1: ')
    
    adverb1 = input('Adverb 1: ')
    adverb2 = input('Adverb 2: ')
    
    matlib = f"""Today, my fabulous camp group went to a/an
    {adjective1} amusement park. It was a
    fun park with lots of cool {noun1}
    and enjoyable play structures. When we got there, my
    kind counselor shouted loudly, "Everybody off the
    {noun2}." We all pushed out in a terrible
    hurry. My counselor handed out yellow tickets, and
    we scurried in. I was so excited! I couldn't figure out
    what exciting thing to do first. I saw a scary roller
    coaster I really liked so, I {adverb1} ran
    over to get in the long line that had about
    {number1} people in it. When I finally
    got on the roller coaster I was {verb1}. 
    In fact I was so nervous my two knees
    were knocking together. This was the
    {adjective2} ride I had ever been on! In about two
    minutes I heard the crank and grinding of the gears.
    That’s when the ride began! When I got to the bottom,
    I was a little {verb2} but I
    was proud of myself. The rest of the day went
    {adverb2}. It was a(n) {adjective3} day at the fun park. """
    
    return matlib

# %%
def At_The_Arcade():
    
    verb1 = input('Verb 1: ')
    verb2 = input('Verb 2(-ing): ')
    
    noun1 = input('Noun 1(plural): ')
    noun2 = input('Noun 2(plural): ')
    noun3 = input('Noun 3: ')
    noun4 = input('Noun 4(plural): ')
    noun5 = input('Noun 5: ')
    noun6 = input('Noun 6(plural): ')
    
    matlib = f"""When I go to the arcade with my {noun1} there are lots of games to play. 
    I spend lots of time there with my friends. In the game X-Men
    you can be different {noun2}. The
    point of the game is to {verb1} every
    robot. You also need to save people. Then you can
    go to the next level.
     In the game Star Wars you are Luke Skywalker
    and you try to destroy every {noun3}. In
    a car racing/motorcycle racing game you need to beat
    every computerized vehicle that you are
    {verb2} against.
    There are a whole lot of other cool games. When
    you play some games you win {noun4} for certain scores. 
    Once you're done you can cash in your tickets to get a big {noun5}. You
    can save your {noun6} for
    another time. When I went to this arcade I didn't
    believe how much fun it would be. So far I have had a
    lot of fun every time I've been to this great arcade!"""
    
    return matlib

# %%
def A_Day_At_The_Zoo():
    adjective1 = input('Adjective 1: ')
    adjective2 = input('Adjective 2: ')
    adjective2 = input('Adjective 2: ')
    
    verb1 = input('Verb 1(-ing): ')
    
    noun1 = input('Noun 1: ')
    noun2 = input('Noun 2: ')
    noun3 = input('Noun 3(proper): ')
    noun4 = input('Noun 4(proper): ')
    noun5 = input('Noun 5(plural): ')
    noun6 = input('Noun 6(plural): ')
    
    number1 = input('Number 1: ')
    
    adverb1 = input('Adverb 1: ')
    
    matlib = f"""One very nice morning near the end of summer,
    my mother woke me up at 4:00 A.M. and said, "Wake
    up and smell the grass, sleepy head! Today is your
    first day of school and you can't be late." I groaned in
    my bed for twenty seconds, but eventually I got
    dressed. I wore a blue and white striped, long sleeve
    {noun1} with a collar on it, a red tie,
    dark gray pants, white socks, black shoes, and a(n)
    {adjective1} hat. In ten minutes I made
    lunch and ate my breakfast. {number1}
    minutes later, the bus came. A few minutes later, I
    was at school.
    In school, I met two really
    {adjective2} kids. All of us became
    friends very fast. That day we had Science, and
    luckily my friends and I were at the same
    {noun2} .My friends' names are
    {noun3} and
    {noun4}. In Math we weren't
    together, and that really bugged me. We learned what
    {noun5} were, and when to use
    them. At snack and recess, we played a game
    together. It was extremely fun. At P. E., we were
    {verb1} off of the ropes onto {noun6}. I thought it was a very
    {adjective3} idea. In swimming class,
    we needed to swim extremely
    {adverb1}, or else we would have to
    swim longer.
    Before I knew it, school was over. I grabbed all
    my belongings and put them into my backpack. In two
    minutes, the bus came. As I stepped into the bus I
    shouted, "Goodbye, adios amigos, and shalom," to
    my friends. Then I went into the bus. In a flash, I was
    back home. This day was an extremely exciting day! """
    
    return matlib

# %%
def The_Great_New_Toy():
    adjective1 = input('Adjective 1: ')
    
    verb1 = input('Verb 1: ')
    verb2 = input('Verb 2: ')
    
    noun1 = input('Noun 1: ')
    noun2 = input('Noun 2(plural): ')
    noun3 = input('Noun 3(plural): ')
    
    number1 = input('Number 1: ')
    number2 = input('Number 2: ')
    
    color1 = input('Color 1: ')
    color2 = input('Color 2: ')
    
    beverage = input('Beverage: ')
    
    sound = input('Sound: ')
    
    exclamation = input('Exclamation: ')
    
    matlib = f"""There is a new toy on the market that has everyone saying
    {exclamation}! It is called the {sound} {adjective1} {noun1} box, 
    and will be in stores in {month}. 
    The {sound} {adjective1} {noun1} box is a new gadget that
    lets you do just about anything!
    It {verb1}s, it {verb2}s, and it even serves
    {beverage}! It is easy to operate and requires no
    instructions!
    You can also have it custom made any size up to
    {number1} inches or a {color1} to glow in the
    dark at no extra charge! The original product is pocket-sized and
    {color2}. There are {number2} jacks on the
    product for 6V DC power and for upgrades and add-ons. You can add
    head-phones, {noun2} monitors, {noun3}, 
    and more! It’s possible to use them all at the same time!"""
    
    return matlib

# %%
def My_Trip_To_Disney_World():
    adjective1 = input('Adjective 1: ')
    adjective2 = input('Adjective 2: ')
    adjective3 = input('Adjective 3: ')
    adjective4 = input('Adjective 4: ')
    
    verb1 = input('Verb 1(-ing): ')
    verb2 = input('Verb 2(past tense): ')
    verb3 = input('Verb 3(past tense): ')
    verb4 = input('Verb 4(past tense): ')
    verb5 = input('Verb 5: ')
    
    noun1 = input('Noun 1: ')
    noun2 = input('Noun 2: ')
    noun3 = input('Noun 3: ')
    
    number1 = input('Number 1: ')
    
    place = input('Place: ')
    friends_name = input('Name: ')
    vehicle = input('vehicle: ')
    animal = input('animal: ')
    
    
    matlib = f"""Last month, I went to Disney World with {friends_name} . We
    traveled for {number1} by {vehicle}. Finally, we
    arrived and it was very {adjective1}. There were
    {adjective2} people {verb1} everywhere. There
    were also people dressed up in {animal} costumes.

    I wish it had been more {adjective3}, but we {verb2} anyway.
    We also went on a(n) {adjective4} ride
    called Magic {noun1}. {friends_name} nearly fell off a ride and had to be
    {verb3}. Later, we went to the hotel and
    {verb4}. Next year, I want to go to {place},
    where we can {verb5}. """
    
    return matlib

# %%
def The_Monkey_King():
    adjective1 = input('Adjective 1: ')
    
    verb1 = input('Verb 1: ')
    
    noun1 = input('Noun 1: ')
    
    adverb1 = input('Adverb 1: ')
    
    matlib = f"""The day I saw the Monkey King {verb1} was one of the most
    interesting days of the year.
    
    After he did that, the king played chess on his brother's
    {noun1} and then combed his {adjective1} hair with a
    comb made out of old fish bones. Later that same day, I saw the
    Monkey King dance {adverb1} in front of an audience of kangaroos and wombats."""
    
    return matlib

# %%
para_list = {'sample':sample, 'A_Day_At_The_Zoo':A_Day_At_The_Zoo, 'The Fun Park': The_Fun_Park, 'At The Arcade': At_The_Arcade,
             'In The Jungle':In_The_Jungle, 'Make Me A Video Game':Make_Me_A_Video_Game, 'The Great New Toy': The_Great_New_Toy,
             'My Trip To Disney World': My_Trip_To_Disney_World, 'The Monkey King': The_Monkey_King}
choice = random.choice(list(para_list.keys()))
print(f'                         {choice}                             ')
print(para_list[choice]())
# Out:
#                          At The Arcade
# Verb 1: ertyr\ger
# Verb 2(-ing): rge
# Noun 1(plural): rth
# Noun 2(plural): dfgd
# Noun 3: fght
# Noun 4(plural): rthr
# Noun 5: dgrt
# Noun 6(plural): try
# When I go to the arcade with my rth there are lots of games to play.
#     I spend lots of time there with my friends. In the game X-Men
#     you can be different dfgd. The
#     point of the game is to ertyr\ger every
#     robot. You also need to save people. Then you can
#     go to the next level.
#      In the game Star Wars you are Luke Skywalker
#     and you try to destroy every fght. In
#     a car racing/motorcycle racing game you need to beat
#     every computerized vehicle that you are
#     rge against.
#     There are a whole lot of other cool games. When
#     you play some games you win rthr for certain scores.
#     Once you're done you can cash in your tickets to get a big dgrt. You
#     can save your try for
#     another time. When I went to this arcade I didn't
# ...
